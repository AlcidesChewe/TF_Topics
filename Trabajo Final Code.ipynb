# %%
import random

class Pokemon:
    def __init__(self, name, type_):
        self.name = name
        self.type = type_
        self.wins = 0

    def __str__(self):
        return f"{self.name} [{self.type}]"

    def add_win(self):
        self.wins += 1

def battle(pokemon1, pokemon2):
    ventaja = {
         "fuego": {"fuego": 0.5, "agua": 0.2, "planta": 0.8, "eléctrico": 0.5, "tierra": 0.5, "roca": 0.2, "volador": 0.8, "fantasma": 0.5, "psiquico": 0.2, "lucha": 0.5, "normal": 0.5},
        "agua": {"fuego": 0.8, "agua": 0.5, "planta": 0.2, "eléctrico": 0.5, "tierra": 0.8, "roca": 0.8, "volador": 0.5, "fantasma": 0.5, "psiquico": 0.2, "lucha": 0.5, "normal": 0.5},
        "planta": {"fuego": 0.2, "agua": 0.8, "planta": 0.5, "eléctrico": 0.5, "tierra": 0.8, "roca": 0.8, "volador": 0.5, "fantasma": 0.5, "psiquico": 0.2, "lucha": 0.5, "normal": 0.5},
        "eléctrico": {"fuego": 0.5, "agua": 0.5, "planta": 0.5, "eléctrico": 0.5, "tierra": 0.8, "roca": 0.2, "volador": 0.5, "fantasma": 0.5, "psiquico": 0.5, "lucha": 0.5, "normal": 0.5},
        "tierra": {"fuego": 0.5, "agua": 0.2, "planta": 0.2, "eléctrico": 0.8, "tierra": 0.5, "roca": 0.8, "volador": 0.2, "fantasma": 0.5, "psiquico": 0.5, "lucha": 0.5, "normal": 0.5},
        "roca": {"fuego": 0.8, "agua": 0.5, "planta": 0.5, "eléctrico": 0.8, "tierra": 0.5, "roca": 0.5, "volador": 0.8, "fantasma": 0.5, "psiquico": 0.5, "lucha": 0.5, "normal": 0.5},
        "volador": {"fuego": 0.2, "agua": 0.8, "planta": 0.8, "eléctrico": 0.5, "tierra": 0.8, "roca": 0.2, "volador": 0.5, "fantasma": 0.5, "psiquico": 0.5, "lucha": 0.5, "normal": 0.5},
        "fantasma": {"fuego": 0.5, "agua": 0.5, "planta": 0.5, "eléctrico": 0.5, "tierra": 0.5, "roca": 0.5, "volador": 0.5, "fantasma": 0.5, "psiquico": 0.8, "lucha": 0.2, "normal": 0.2},
        "psiquico": {"fuego": 0.8, "agua": 0.8, "planta": 0.8, "eléctrico": 0.5, "tierra": 0.5, "roca": 0.5, "volador": 0.5, "fantasma": 0.2, "psiquico": 0.5, "lucha": 0.2, "normal": 0.2},
        "lucha": {"fuego": 0.5, "agua": 0.5, "planta": 0.5, "eléctrico": 0.5, "tierra": 0.5, "roca": 0.5, "volador": 0.8, "fantasma": 0.8, "psiquico": 0.8, "lucha": 0.5, "normal": 0.5},
        "normal": {"fuego": 0.5, "agua": 0.5, "planta": 0.5, "eléctrico": 0.5, "tierra": 0.5, "roca": 0.5, "volador": 0.5, "fantasma": 0.5, "psiquico": 0.5, "lucha": 0.5, "normal": 0.5}
    }

    prob_poke1_gana = ventaja[pokemon1.type][pokemon2.type]
    prob_poke2_wins = 1 - prob_poke1_gana

    winner = pokemon1 if random.random() < prob_poke1_gana else pokemon2
    return winner

def crear_poke(n):
    tipos = ["fuego", "agua", "planta", "eléctrico",
             "tierra", "roca", "volador", "fantasma",
             "psíquico", "lucha", "normal"]
    pokemons = []
    for i in range(n):
        name = f"Poke{i+1}"
        tipo = random.choice(tipos)
        pokemons.append(Pokemon(name, tipo))
    return pokemons

def main():
    pokemons = crear_poke(10)

    print("Lista de pokemones iniciales:")
    for pokemon in pokemons:
        print(pokemon)

    round_num = 1
    all_pokemons = pokemons.copy()

    while len(pokemons) > 1:
        print("\nronda", round_num)
        poke1, poke2 = random.sample(pokemons, 2)
        winner = battle(poke1, poke2)
        winner.add_win()
        loser = poke1 if winner == poke2 else poke2
        print(poke1,"vs",poke2,"=>","gano",winner)
        pokemons.remove(loser)
        round_num += 1

    print(f"\n¡El ganador es {pokemons[0]}!\n")

    print("Resultados finales:")
    for pokemon in all_pokemons:
        print(pokemon, ":",pokemon.wins,"victorias")

if __name__ == "__main__":
    main()
# Out:
# Lista de pokemones iniciales:
# Poke1 [lucha]
# Poke2 [roca]
# Poke3 [volador]
# Poke4 [fuego]
# Poke5 [roca]
# Poke6 [normal]
# Poke7 [fantasma]
# Poke8 [roca]
# Poke9 [eléctrico]
# Poke10 [roca]
#
# ronda 1
# Poke7 [fantasma] vs Poke10 [roca] => gano Poke10 [roca]
#
# ronda 2
# Poke4 [fuego] vs Poke9 [eléctrico] => gano Poke4 [fuego]
#
# ronda 3
# Poke4 [fuego] vs Poke2 [roca] => gano Poke2 [roca]
#
# ronda 4
# Poke5 [roca] vs Poke1 [lucha] => gano Poke5 [roca]
#
# ronda 5
# Poke6 [normal] vs Poke2 [roca] => gano Poke6 [normal]
#
# ronda 6
# Poke10 [roca] vs Poke3 [volador] => gano Poke3 [volador]
#
# ronda 7
# Poke6 [normal] vs Poke8 [roca] => gano Poke6 [normal]
#
# ronda 8
# Poke5 [roca] vs Poke3 [volador] => gano Poke5 [roca]
#
# ronda 9
# Poke6 [normal] vs Poke5 [roca] => gano Poke5 [roca]
#
# ¡El ganador es Poke5 [roca]!
#
# Resultados finales:
# Poke1 [lucha] : 0 victorias
# Poke2 [roca] : 1 victorias
# Poke3 [volador] : 1 victorias
# Poke4 [fuego] : 1 victorias
# Poke5 [roca] : 3 victorias
# Poke6 [normal] : 2 victorias
# Poke7 [fantasma] : 0 victorias
# Poke8 [roca] : 0 victorias
# Poke9 [eléctrico] : 0 victorias
# Poke10 [roca] : 1 victorias

# %%
import random

class Pokemon:
    def __init__(self, name, type_):
        self.name = name
        self.type = type_
        self.wins = 0

    def __str__(self):
        return f"{self.name} [{self.type}]"

    def add_win(self):
        self.wins += 1

def battle(pokemon1, pokemon2):
    type_advantage = {
        "fuego": {"fuego": 0.5, "agua": 0.2, "planta": 0.8},
        "agua": {"fuego": 0.8, "agua": 0.5, "planta": 0.2},
        "planta": {"fuego": 0.2, "agua": 0.8, "planta": 0.5},
        "volador": {"volador": 0.5, "lucha": 0.5, "psíquico": 0.5},
        "lucha": {"volador": 0.5, "lucha": 0.5, "psíquico": 0.5},
        "psíquico": {"volador": 0.5, "lucha": 0.5, "psíquico": 0.5}
    }

    prob_poke1_wins = type_advantage[pokemon1.type][pokemon2.type]
    prob_poke2_wins = 1 - prob_poke1_wins

    winner = pokemon1 if random.random() < prob_poke1_wins else pokemon2
    return winner

def create_pokemons(n):
    types = ["fuego", "agua", "planta", "volador", "lucha", "psíquico"]
    pokemons = []
    for i in range(n):
        name = f"Poke{i+1}"
        type_ = random.choice(types)
        pokemons.append(Pokemon(name, type_))
    return pokemons

def main():
    pokemons = create_pokemons(10)

    print("Lista de pokemones iniciales:")
    for pokemon in pokemons:
        print(pokemon)

    round_num = 1
    all_pokemons = pokemons.copy()  # Keep a copy of all initial pokemons for final stats

    while len(pokemons) > 1:
        print(f"\n--- Round {round_num} ---")
        poke1, poke2 = random.sample(pokemons, 2)
        winner = battle(poke1, poke2)
        winner.add_win()
        loser = poke1 if winner == poke2 else poke2
        print(f"{poke1} vs {poke2} => Ganó {winner}")
        pokemons.remove(loser)
        round_num += 1

    print(f"\n¡El ganador es {pokemons[0]}!\n")

    print("Resultados finales:")
    for pokemon in all_pokemons:
        print(f"{pokemon}: {pokemon.wins} victorias")

if __name__ == "__main__":
    main()

# %%
import random

class Pokemon(Agent):
    def __init__(self, name, type_):
        super().__init__(program=self.program)
        self.name = name
        self.type = type_
        self.wins = 0
        self.alive = True
        self.location = None

    def __str__(self):
        return f"{self.name} [{self.type}]"

    def add_win(self):
        self.wins += 1

    def program(self, percept):
        # Always choose to move or stay, and look for battles
        return random.choice(["move", "stay"])

def battle(pokemon1, pokemon2):
    ventaja = {
        "fuego": {"fuego": 0.5, "agua": 0.2, "planta": 0.8, "eléctrico": 0.5, "tierra": 0.5, "roca": 0.2, "volador": 0.8, "fantasma": 0.5, "psiquico": 0.2, "lucha": 0.5, "normal": 0.5},
        "agua": {"fuego": 0.8, "agua": 0.5, "planta": 0.2, "eléctrico": 0.5, "tierra": 0.8, "roca": 0.8, "volador": 0.5, "fantasma": 0.5, "psiquico": 0.2, "lucha": 0.5, "normal": 0.5},
        "planta": {"fuego": 0.2, "agua": 0.8, "planta": 0.5, "eléctrico": 0.5, "tierra": 0.8, "roca": 0.8, "volador": 0.5, "fantasma": 0.5, "psiquico": 0.2, "lucha": 0.5, "normal": 0.5},
        "eléctrico": {"fuego": 0.5, "agua": 0.5, "planta": 0.5, "eléctrico": 0.5, "tierra": 0.8, "roca": 0.2, "volador": 0.5, "fantasma": 0.5, "psiquico": 0.5, "lucha": 0.5, "normal": 0.5},
        "tierra": {"fuego": 0.5, "agua": 0.2, "planta": 0.2, "eléctrico": 0.8, "tierra": 0.5, "roca": 0.8, "volador": 0.2, "fantasma": 0.5, "psiquico": 0.5, "lucha": 0.5, "normal": 0.5},
        "roca": {"fuego": 0.8, "agua": 0.5, "planta": 0.5, "eléctrico": 0.8, "tierra": 0.5, "roca": 0.5, "volador": 0.8, "fantasma": 0.5, "psiquico": 0.5, "lucha": 0.5, "normal": 0.5},
        "volador": {"fuego": 0.2, "agua": 0.8, "planta": 0.8, "eléctrico": 0.5, "tierra": 0.8, "roca": 0.2, "volador": 0.5, "fantasma": 0.5, "psiquico": 0.5, "lucha": 0.5, "normal": 0.5},
        "fantasma": {"fuego": 0.5, "agua": 0.5, "planta": 0.5, "eléctrico": 0.5, "tierra": 0.5, "roca": 0.5, "volador": 0.5, "fantasma": 0.5, "psiquico": 0.8, "lucha": 0.2, "normal": 0.2},
        "psiquico": {"fuego": 0.8, "agua": 0.8, "planta": 0.8, "eléctrico": 0.5, "tierra": 0.5, "roca": 0.5, "volador": 0.5, "fantasma": 0.2, "psiquico": 0.5, "lucha": 0.2, "normal": 0.2},
        "lucha": {"fuego": 0.5, "agua": 0.5, "planta": 0.5, "eléctrico": 0.5, "tierra": 0.5, "roca": 0.5, "volador": 0.8, "fantasma": 0.8, "psiquico": 0.8, "lucha": 0.5, "normal": 0.5},
        "normal": {"fuego": 0.5, "agua": 0.5, "planta": 0.5, "eléctrico": 0.5, "tierra": 0.5, "roca": 0.5, "volador": 0.5, "fantasma": 0.5, "psiquico": 0.5, "lucha": 0.5, "normal": 0.5}
    }

    prob_poke1_gana = ventaja[pokemon1.type][pokemon2.type]
    winner = pokemon1 if random.random() < prob_poke1_gana else pokemon2
    return winner

# %%
# !pip install ipythonblocks

# %%
from utils import *
from agents import *
import random
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

class Park2D(Environment):
    def __init__(self, width, height):
        super().__init__()
        self.width = width
        self.height = height
        self.grid = [[None for _ in range(width)] for _ in range(height)]

    def add_thing(self, thing, location):
        super().add_thing(thing, location)
        x, y = location
        self.grid[y][x] = thing
        thing.location = location

    def move_thing(self, thing, new_location):
        x, y = thing.location
        self.grid[y][x] = None
        x, y = new_location
        self.grid[y][x] = thing
        thing.location = new_location

    def step(self):
        for y in range(self.height):
            for x in range(self.width):
                if self.grid[y][x] and self.grid[y][x].alive:
                    self.execute_action(self.grid[y][x], self.grid[y][x].program(None))

    def execute_action(self, agent, action):
        if action == "move":
            direction = random.choice(["up", "down", "left", "right"])
            x, y = agent.location
            if direction == "up" and y > 0:
                new_location = (x, y - 1)
            elif direction == "down" and y < self.height - 1:
                new_location = (x, y + 1)
            elif direction == "left" and x > 0:
                new_location = (x - 1, y)
            elif direction == "right" and x < self.width - 1:
                new_location = (x + 1, y)
            else:
                return

            if self.grid[new_location[1]][new_location[0]] is None:
                self.move_thing(agent, new_location)
            else:
                opponent = self.grid[new_location[1]][new_location[0]]
                if opponent and opponent.alive:
                    winner = battle(agent, opponent)
                    winner.add_win()
                    loser = agent if winner == opponent else opponent
                    loser.alive = False
                    x, y = loser.location
                    self.grid[y][x] = None

    def is_done(self):
        return all(pokemon.alive for row in self.grid for pokemon in row if pokemon)

    def visualize(self):
        colors = {"fuego": 1, "agua": 2, "planta": 3, "eléctrico": 4, "tierra": 5, "roca": 6, "volador": 7, "fantasma": 8, "psiquico": 9, "lucha": 10, "normal": 11, None: 0}
        cmap = ListedColormap(["white", "red", "blue", "green", "yellow", "brown", "grey", "orange", "purple", "pink", "black", "cyan"])

        grid_colors = [[colors[self.grid[y][x].type] if self.grid[y][x] else 0 for x in range(self.width)] for y in range(self.height)]
        plt.figure(figsize=(10, 10))
        plt.imshow(grid_colors, cmap=cmap, origin="upper")
        plt.title("Pokémon Simulation")
        plt.show()

# %%
def create_pokemons(n):
    types = ["fuego", "agua", "planta", "eléctrico", "tierra", "roca", "volador", "fantasma", "psiquico", "lucha", "normal"]
    pokemons = []
    for i in range(n):
        name = f"Poke{i+1}"
        type_ = random.choice(types)
        pokemons.append(Pokemon(name, type_))
    return pokemons

def initialize_park(park, pokemons):
    for pokemon in pokemons:
        while True:
            x, y = random.randint(0, park.width - 1), random.randint(0, park.height - 1)
            if park.grid[y][x] is None:
                park.add_thing(pokemon, (x, y))
                break

def main():
    width, height = 5, 5
    park = Park2D(width, height)
    pokemons = create_pokemons(25)
    initialize_park(park, pokemons)

    iterations = 10  # or any number of steps you want to simulate
    for i in range(iterations):
        park.step()
        park.visualize()
        # Optional: Add a pause or delay to observe each step
        plt.pause(0.1)

    print("Simulation complete.")
    # Optional: Print results or final state of the park

if __name__ == "__main__":
    main()
# Out:
# Simulation complete.
